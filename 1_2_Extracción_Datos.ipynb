# %% [markdown]
# <a href="https://colab.research.google.com/github/renatachavezm22/Extraccion-de-datos-ACT1/blob/main/1_2_Extraccio%CC%81n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b3971ff8-e08f-4a1c-bc2a-8837533c328c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3971ff8-e08f-4a1c-bc2a-8837533c328c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# CARGA DE ARCHIVO .CSV

# %%
#Convertir en dataframe
#df= pd.read_csv("file.csv")
#df

# %% [markdown]
# CARGA DE ARCHIVO XLSX

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('Datos de Facturacion Bueno.xlsx')
df
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414    2465.0      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415    3926.0      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416    3926.0      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417    3926.0      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418    6813.0      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306    8842.0      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307    6218.0      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308    5926.0      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309     361.0      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310    3011.0      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10895 non-null  object
#  1   CVE_CLPV       10894 non-null  float64
#  2   STATUS         10895 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10895 non-null  datetime64[ns]
#  5   FECHA_DOC      10895 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10895 non-null  float64
#  10  DES_TOT        10895 non-null  float64
#  11  DES_FIN        10895 non-null  int64
# dtypes: datetime64[ns](4), float64(4), int64(1), object(3)
# memory usage: 1021.5+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
df.head()
# Out:
#   CVE_DOC  CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414    2465.0      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415    3926.0      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416    3926.0      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417    3926.0      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418    6813.0      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04  3980.00      0.0        0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0        0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0        0
# 3  2019-09-03 00:00:00 2019-10-03    2019-09-17  1550.00      0.0        0
# 4  2019-09-03 00:00:00 2019-09-03    2019-09-10  2435.44      0.0        0

# %%
#Filtro 1
filtro1=df[(df["CVE_CLPV"] >= 1000) & (df["CVE_CLPV"] <= 2000)]
filtro1
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 18     F29432    1965.0      C       2.0 2019-09-05 11:05:04.000 2019-09-05
# 22     F29436    1965.0      C       2.0 2019-09-06 12:01:36.000 2019-09-06
# 65     F29479    1240.0      E       2.0 2019-09-11 18:38:45.000 2019-09-11
# 71     F29485    1965.0      C       2.0 2019-09-12 12:14:28.000 2019-09-12
# 72     F29486    1965.0      E       2.0 2019-09-12 12:25:52.000 2019-09-12
# ...       ...       ...    ...       ...                     ...        ...
# 10821  F40237    1757.0      E       2.0 2023-02-24 15:18:17.570 2023-02-24
# 10839  F40255    1583.0      E       2.0 2023-02-28 09:15:45.753 2023-02-28
# 10845  F40261    1786.0      E       2.0 2023-02-28 11:15:32.527 2023-02-28
# 10871  F40287    1453.0      E       1.0 2023-03-01 12:58:23.397 2023-03-01
# 10876  F40292    1082.0      E       6.0 2023-03-02 11:00:54.770 2023-03-02
#
# ...

# %%
filtro2=df[~(df["CVE_VEND"] == 5.0) & ~(df["CVE_VEND"] == 4.0)]
filtro2
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414    2465.0      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415    3926.0      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416    3926.0      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417    3926.0      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418    6813.0      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306    8842.0      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307    6218.0      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308    5926.0      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309     361.0      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310    3011.0      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
filtro3=df[df["FECHA_ENT"] == "2022-02-28"]
filtro3
# Out:
# Empty DataFrame
# Columns: [CVE_DOC, CVE_CLPV, STATUS, CVE_VEND, FECHAELAB, FECHA_DOC, FECHA_ENT, FECHA_VEN, FECHA_CANCELA, CAN_TOT, DES_TOT, DES_FIN]
# Index: []

# %%
filtro4= df[(df['CAN_TOT'] < 5951.7) | (df['STATUS']== "E")]
filtro4
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414         0      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415         0      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416         0      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417         0      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418         0      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306         0      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307         0      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308         0      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         0      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310         0      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
filtro5=df.loc[ : , ["CVE_DOC", "FECHA_ENT", "FECHA_VEN", "CAN_TOT"]]
filtro5
# Out:
#       CVE_DOC            FECHA_ENT  FECHA_VEN  CAN_TOT
# 0      F29414  2019-09-03 00:00:00 2019-09-18  3980.00
# 1      F29415  2019-09-03 00:00:00 2019-10-03  1550.00
# 2      F29416  2019-09-03 00:00:00 2019-10-03  1550.00
# 3      F29417  2019-09-03 00:00:00 2019-10-03  1550.00
# 4      F29418  2019-09-03 00:00:00 2019-09-03  2435.44
# ...       ...                  ...        ...      ...
# 10890  F40306  2023-03-01 00:00:00 2023-03-06  3272.00
# 10891  F40307  2023-03-06 00:00:00 2023-03-06   504.15
# 10892  F40308  2023-03-06 00:00:00 2023-03-06   275.68
# 10893  F40309  2023-03-07 00:00:00 2023-03-07   129.30
# 10894  F40310  2023-03-01 00:00:00 2023-03-07   517.20
#
# [10895 rows x 4 columns]

# %%
filtro6= df.iloc[7001:7100,: ]
filtro6
# Out:
#      CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 7001  F36417         0      E       3.0 2021-10-15 08:40:29.183 2021-10-15
# 7002  F36418         0      E       2.0 2021-10-15 08:51:03.463 2021-10-15
# 7003  F36419         0      E       3.0 2021-10-15 08:56:23.280 2021-10-15
# 7004  F36420         0      E       1.0 2021-10-15 09:01:08.393 2021-10-15
# 7005  F36421         0      E       1.0 2021-10-15 09:07:07.103 2021-10-15
# ...      ...       ...    ...       ...                     ...        ...
# 7095  F36511         0      E       2.0 2021-10-27 13:07:43.223 2021-10-27
# 7096  F36512         0      E       2.0 2021-10-27 13:22:23.980 2021-10-27
# 7097  F36513         0      E       2.0 2021-10-27 13:35:40.677 2021-10-27
# 7098  F36514         0      E       2.0 2021-10-27 14:02:54.630 2021-10-27
# 7099  F36515         0      E       2.0 2021-10-27 14:04:26.797 2021-10-27
#
# ...

# %%
df1= pd.read_excel('Datos de Facturación.xlsx', index_col=3)
df1
# Out:
#          CVE_DOC  CVE_CLPV STATUS               FECHAELAB  FECHA_DOC  \
# CVE_VEND
# 1.0       F29414    2465.0      C 2019-09-03 08:58:42.000 2019-09-03
# 1.0       F29415    3926.0      C 2019-09-03 09:55:14.000 2019-09-03
# 1.0       F29416    3926.0      C 2019-09-03 13:25:33.000 2019-09-03
# 1.0       F29417    3926.0      C 2019-09-03 13:33:23.000 2019-09-03
# 2.0       F29418    6813.0      C 2019-09-03 14:23:45.000 2019-09-03
# ...          ...       ...    ...                     ...        ...
# 2.0       F40306    8842.0      E 2023-03-06 16:09:39.013 2023-03-06
# 2.0       F40307    6218.0      E 2023-03-06 16:38:42.933 2023-03-06
# 2.0       F40308    5926.0      E 2023-03-06 17:02:33.390 2023-03-06
# 2.0       F40309     361.0      E 2023-03-07 12:43:49.567 2023-03-07
# 2.0       F40310    3011.0      E 2023-03-07 12:45:58.407 2023-03-07
#
#                     FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  \
# CVE_VEND
# ...

# %%
filtro7=df1.loc[[1.0,2.0], ["FECHAELAB"]]
filtro7
# Out:
#                        FECHAELAB
# CVE_VEND
# 1.0      2019-09-03 08:58:42.000
# 1.0      2019-09-03 09:55:14.000
# 1.0      2019-09-03 13:25:33.000
# 1.0      2019-09-03 13:33:23.000
# 1.0      2019-09-04 09:15:12.000
# ...                          ...
# 2.0      2023-03-06 16:09:39.013
# 2.0      2023-03-06 16:38:42.933
# 2.0      2023-03-06 17:02:33.390
# 2.0      2023-03-07 12:43:49.567
# 2.0      2023-03-07 12:45:58.407
#
# [8665 rows x 1 columns]

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("FILTRO1_2.csv")
filtro2.to_csv("FILTRO2_2.csv")
filtro3.to_csv("FILTRO3_2.csv")
filtro4.to_csv("FILTRO4_2.csv")
filtro5.to_csv("FILTRO5_2.csv")
filtro6.to_csv("FILTRO6_2.csv")
filtro7.to_csv("FILTRO7_2.csv")

# %%
from google.colab import files 
  
files.download("FILTRO1_2.csv")
files.download("FILTRO2_2.csv")
files.download("FILTRO3_2.csv")
files.download("FILTRO4_2.csv")
files.download("FILTRO5_2.csv")
files.download("FILTRO6_2.csv")
files.download("FILTRO7_2.csv")
